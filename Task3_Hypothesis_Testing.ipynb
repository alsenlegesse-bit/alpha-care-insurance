# %% [markdown]
# # Task 3: Hypothesis Testing
# ## AlphaCare Insurance Solutions

# %%
# Basic imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Load data
try:
    df = pd.read_csv('insurance_data.csv')
except:
    print("Sample data will be used for demonstration")
    # Create sample data
    np.random.seed(42)
    n = 500
    df = pd.DataFrame({
        'Province': np.random.choice(['Gauteng', 'WC', 'KZN'], n),
        'Gender': np.random.choice(['Male', 'Female'], n),
        'TotalPremium': np.random.normal(5000, 1500, n),
        'TotalClaims': np.random.exponential(800, n)
    })

print(f"Data shape: {df.shape}")
